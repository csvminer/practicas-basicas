# %% [markdown]
# Objetivo: Predecir elprecio de venta de una vivienda

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('/content/Datos_viviendas.csv')

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tamanio           317 non-null    int64
#  1   num_habitaciones  317 non-null    int64
#  2   antiguedad        317 non-null    int64
#  3   precio            317 non-null    int64
# dtypes: int64(4)
# memory usage: 10.0 KB

# %%
df.shape
# Out:
# (317, 4)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# tamanio             0
# num_habitaciones    0
# antiguedad          0
# precio              0
# dtype: int64

# %%
df.head()
# Out:
#    tamanio  num_habitaciones  antiguedad  precio
# 0      120                 3           5  250000
# 1      150                 4          10  300000
# 2       90                 2          15  180000
# 3      180                 5           2  400000
# 4      100                 3           8  220000

# %%
x = df.drop('precio', axis=1)
y = df['precio']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Entrenar al modelo
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Realizar predicciones en el conjunto de prueba
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 1886655.19765695, 11180034.4912109 ,   287384.75763083,
#        10057645.68764158,   320424.04485494,  3143730.65765459,
#         6510897.06836254,  6959852.58979027,  1437699.67622923,
#         3817163.93979618,  9339316.85335721,  1976446.3019425 ,
#         5972150.44264927,  6376210.41193422,  8037345.84121681,
#         2380506.27122745,  6914957.03764749,  4535492.77408054,
#        12616692.15977962,  9608690.16621386,  7678181.42407463,
#         6555792.62050531,  7453703.66336076,  3457999.522654  ,
#          542318.14090566,  3906955.04408172, 11808572.22120971,
#          231794.02445821,  3727372.83551063,  6780270.38121917,
#         4266119.4612239 ,   287384.75763083,  6106837.09907759,
#         9788272.37478494, 11943258.87763803,  2066237.40622804,
#         6466001.51621977,  7319017.00693245,  4759970.5347944 ,
#         6151732.65122036,   398358.88422182,  5208926.05622213,
#        11269825.59549644, 11090243.38692535,   690283.64302698,
#          465094.59192595,  4894657.19122272,  9384212.40549999,
#         8620988.01907285,  2290715.16694191,  1168326.36337259,
#         8980152.43621504,  6017045.99479204,   653292.26749665,
#          381839.24060977,  6870061.48550472,  3278417.31408291,
#         1303013.01980091,   261592.51376326,  8441405.81050177,
#         7947554.73693126,  3502895.07479677,  2784566.24051241,
#         4176328.35693836])

# %%
# Evaluar el rendimiento
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Error cuadrático medio (MSE): {mse}")
print(f"R^2: {r2}")
# Out:
# Error cuadrático medio (MSE): 200607743.96428603
# R^2: 0.9999842514136227

# %% [markdown]
# Conclusion:
